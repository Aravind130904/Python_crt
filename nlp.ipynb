# %%
pip install nltk
# Out:
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.5 MB 441.3 kB/s eta 0:00:03
#    ------------- -------------------------- 0.5/1.5 MB 441.3 kB/s eta 0:00:03
#    ------------- -------------------------- 0.5/1.5 MB 441.3 kB/s eta 0:00:03
#    ------------- -------------------------- 0.5/1.5 MB 441.3 kB/s eta 0:00:03
#    ------------- -------------------------- 0.5/1.5 MB 441.3 kB/s eta 0:00:03
#    ------------- -------------------------- 0.5/1.5 MB 441.3 kB/s eta 0:00:03
#    ------------- -------------------------- 0.5/1.5 MB 441.3 kB/s eta 0:00:03
#    -------------------- ------------------- 0.8/1.5 MB 252.3 kB/s eta 0:00:03
# ...

# %%
pip install spacy
# Out:
# ...
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.8 MB ? eta -:--:--
# ...

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/singhrau0/Big-Data-Preprocessing/refs/heads/main/titanic_dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[df['Gender']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name Gender  \
# 0              1         0       3         Braund, Mr. Owen Harris   male
# 4              5         0       3        Allen, Mr. William Henry   male
# 5              6         0       3                Moran, Mr. James   male
# 6              7         0       1         McCarthy, Mr. Timothy J   male
# 7              8         0       3  Palsson, Master. Gosta Leonard   male
# ..           ...       ...     ...                             ...    ...
# 883          884         0       2   Banfield, Mr. Frederick James   male
# 884          885         0       3          Sutehall, Mr. Henry Jr   male
# 886          887         0       2           Montvila, Rev. Juozas   male
# 889          890         1       1           Behr, Mr. Karl Howell   male
# 890          891         0       3             Dooley, Mr. Patrick   male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df[df['Gender']=='female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Gender']=='male')&(df['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass                             Name Gender  \
# 17            18         1       2     Williams, Mr. Charles Eugene   male
# 21            22         1       2            Beesley, Mr. Lawrence   male
# 23            24         1       1     Sloper, Mr. William Thompson   male
# 36            37         1       3                 Mamee, Mr. Hanna   male
# 55            56         1       1                Woolner, Mr. Hugh   male
# ..           ...       ...     ...                              ...    ...
# 838          839         1       3                  Chip, Mr. Chang   male
# 839          840         1       1             Marechal, Mr. Pierre   male
# 857          858         1       1           Daly, Mr. Peter Denis    male
# 869          870         1       3  Johnson, Master. Harold Theodor   male
# 889          890         1       1            Behr, Mr. Karl Howell   male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
df[(df['Gender']=='female')&(df['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Age']>50]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 54            55         0       1
# ..           ...       ...     ...
# 820          821         1       1
# 829          830         1       1
# 851          852         0       3
# 857          858         1       1
# 879          880         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 54                      Ostby, Mr. Engelhart Cornelius    male  65.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#updateting
df.loc[df['Age']>50,'Fare']=0

# %%
df[df['Age']>50]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 54            55         0       1
# ..           ...       ...     ...
# 820          821         1       1
# 829          830         1       1
# 851          852         0       3
# 857          858         1       1
# 879          880         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 54                      Ostby, Mr. Engelhart Cornelius    male  65.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#update the value of fare whose age is greater than 30 and gender is female to 45 
df[(df['Gender']=='female')&(df['Age']>30)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 15            16         1       2
# 18            19         0       3
# ..           ...       ...     ...
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# update the fare 
df.loc[(df['Gender']=='female')&(df['Age']>30),'Fare']=450

# %%
df[(df['Gender']=='female')&(df['Age']>30)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 15            16         1       2
# 18            19         0       3
# ..           ...       ...     ...
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# increase the fare prices by 30% whose pclass is 1 and age is greater than 15
df[(df['Pclass']==1)&(df['Age']>15)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[(df['Pclass']==1)&(df['Age']>15),'Fare']=df['Fare']*1.3

# %%
df[(df['Pclass']==1)&(df['Age']>15)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.loc[df['Age'].isnull(),'Age']=29.69

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          529
# Embarked         2
# dtype: int64

# %%
df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df.loc[df['Embarked'].isnull(),'Embarked']='S'

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          529
# Embarked         0
# dtype: int64

# %%
import pandas as pd
dt = pd.read_csv("https://raw.githubusercontent.com/singhrau0/Big-Data-Preprocessing/refs/heads/main/youtubesample.csv")
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 1     2yCp-Dj5-7c      17.16.12
# 2     H00djJq68VE      17.27.12
# 3     oTObwUiXdYY      17.19.11
# 4     yvicqMrAHvQ      18.05.02
# ...           ...           ...
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title  \
# 0     MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...
# 1     Does Tiffany Haddish Think NeNe Leakes Is Funn...
# 2     Panettone (Italian Christmas Bread) - Food Wishes
# 3     7.3 Magnitude Earthquake Along Iraq-Iran Borde...
# 4               Turkish Airlines - 5 Senses with Dr. Oz
# ...                                                 ...
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice
# 4996                   God of War – Story Trailer | PS4
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don
# ...

# %%
dt
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 1     2yCp-Dj5-7c      17.16.12
# 2     H00djJq68VE      17.27.12
# 3     oTObwUiXdYY      17.19.11
# 4     yvicqMrAHvQ      18.05.02
# ...           ...           ...
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title  \
# 0     MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...
# 1     Does Tiffany Haddish Think NeNe Leakes Is Funn...
# 2     Panettone (Italian Christmas Bread) - Food Wishes
# 3     7.3 Magnitude Earthquake Along Iraq-Iran Borde...
# 4               Turkish Airlines - 5 Senses with Dr. Oz
# ...                                                 ...
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice
# 4996                   God of War – Story Trailer | PS4
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don
# ...

# %%
dt[dt['title'].str.contains('INSTAGRAM')]
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 56    s4kX4R6T9ms      18.07.04
# 319   m8Dqg8iz5Fo      18.14.05
# 2927  oY9GVZKwBhI      18.01.05
# 3094  ms7t4CnjW1k      18.26.02
# 3281  oY9GVZKwBhI      18.08.05
#
#                                                   title channel_title  \
# 0     MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...   Sylvia Gani
# 56    VIRAL INSTAGRAM ONE-SWIPE EYESHADOW Review (fi...   heyitsfeiii
# 319   MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...   Sylvia Gani
# 2927          COPYING MADDIE ZIEGLER'S INSTAGRAM PHOTOS    Jess Conte
# 3094                          HOW I EDIT MY INSTAGRAMS!   FunForLouis
# 3281          COPYING MADDIE ZIEGLER'S INSTAGRAM PHOTOS    Jess Conte
#
#       category_id              publish_time  \
# 0              26  2018-04-30T00:18:19.000Z
# 56             26  2018-04-04T22:00:03.000Z
# 319            26  2018-04-30T00:18:19.000Z
# 2927           24  2018-04-26T00:55:12.000Z
# ...

# %%
# fetch those videos which are having gaming tags
dt[dt['tags'].str.contains('game')]
# Out:
#          video_id trending_date  \
# 15    d1hs-JI_yBE      17.27.12
# 19    upzmEBwEtpo      17.09.12
# 20    xtR7m-Fl-F0      18.11.03
# 21    Xr2rgT9uEnA      18.26.05
# 28    doP7xKdGOKs      18.10.02
# ...           ...           ...
# 4872  KU-v13ib_1U      18.05.02
# 4954  JcdLF6XQ0iw      17.22.12
# 4970  aphpJi5jKrM      17.15.12
# 4977  uVcvhKTVZ8g      18.04.05
# 4998  vGTTSdrV37U      18.04.04
#
#                                                   title  channel_title  \
# 15    Kobe Bryant No.8 & No.24 Jersey Retirement In ...            NBA
# 19    21 Things that Turned 21 This Year (2017) - me...   Mental Floss
# 20                             I Went to a Butler Cafe.     akidearest
# 21                LIE DETECTOR TEST WITH MY GIRLFRIEND!     miniminter
# 28    Tide | Super Bowl LII 2018 Commercial | It's a...           Tide
# ...                                                 ...            ...
# 4872                Puppy Bowl Spot Center: Top 5 Plays  Animal Planet
# ...

# %%
dt['thumbnail_link'].str.split('/')
# Out:
# 0       [https:, , i.ytimg.com, vi, m8Dqg8iz5Fo, defau...
# 1       [https:, , i.ytimg.com, vi, 2yCp-Dj5-7c, defau...
# 2       [https:, , i.ytimg.com, vi, H00djJq68VE, defau...
# 3       [https:, , i.ytimg.com, vi, oTObwUiXdYY, defau...
# 4       [https:, , i.ytimg.com, vi, yvicqMrAHvQ, defau...
#                               ...
# 4995    [https:, , i.ytimg.com, vi, bqFjyo7I8fY, defau...
# 4996    [https:, , i.ytimg.com, vi, K0u_kAWLJOA, defau...
# 4997    [https:, , i.ytimg.com, vi, XGd1dq1BatM, defau...
# 4998    [https:, , i.ytimg.com, vi, vGTTSdrV37U, defau...
# 4999    [https:, , i.ytimg.com, vi, DkeiKbqa02g, defau...
# Name: thumbnail_link, Length: 5000, dtype: object

# %%
dt['thumbnail_link'].str.split('/').str[4]
# Out:
# 0       m8Dqg8iz5Fo
# 1       2yCp-Dj5-7c
# 2       H00djJq68VE
# 3       oTObwUiXdYY
# 4       yvicqMrAHvQ
#            ...
# 4995    bqFjyo7I8fY
# 4996    K0u_kAWLJOA
# 4997    XGd1dq1BatM
# 4998    vGTTSdrV37U
# 4999    DkeiKbqa02g
# Name: thumbnail_link, Length: 5000, dtype: object

# %%
dt['thumbnail_link'].str.split('/').str[4].str.upper()
# Out:
# 0       M8DQG8IZ5FO
# 1       2YCP-DJ5-7C
# 2       H00DJJQ68VE
# 3       OTOBWUIXDYY
# 4       YVICQMRAHVQ
#            ...
# 4995    BQFJYO7I8FY
# 4996    K0U_KAWLJOA
# 4997    XGD1DQ1BATM
# 4998    VGTTSDRV37U
# 4999    DKEIKBQA02G
# Name: thumbnail_link, Length: 5000, dtype: object

# %%
dt['channel_title'].str.split(' ').str[0]
# Out:
# 0                 Sylvia
# 1                  Watch
# 2                   Food
# 3                   TIME
# 4                Turkish
#               ...
# 4995              SMTOWN
# 4996         PlayStation
# 4997          HalseyVEVO
# 4998         Nickelodeon
# 4999    CalvinHarrisVEVO
# Name: channel_title, Length: 5000, dtype: object

# %%
dt['description'].str.contains('http')
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 4995     True
# 4996     True
# 4997     True
# 4998     True
# 4999     True
# Name: description, Length: 5000, dtype: object

# %%
dt['description'].str.find('http')
# Out:
# 0        16.0
# 1       226.0
# 2       136.0
# 3       258.0
# 4        -1.0
#         ...
# 4995     76.0
# 4996      0.0
# 4997     21.0
# 4998    345.0
# 4999     74.0
# Name: description, Length: 5000, dtype: float64
